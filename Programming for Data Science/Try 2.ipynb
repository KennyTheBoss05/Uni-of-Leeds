# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
f=pd.read_csv("Spotify_Dataset_V3.csv",delimiter=";")
#print(df.head())
#f.head() shows there are some columns in the dataset that are irrelevant to this project
#Preparing the dataset by removing unnecessary columns:
f = f.drop(["# of Artist","# of Nationality","Points (Total)","Points (Ind for each Artist/Nat)","Artist (Ind.)",],axis=1)

# %%
df = f.loc[0:19999,]
#df = f
print(df)
# Out:
#        Rank            Title                        Artists        Date  \
# 0         1  Ella Baila Sola     Eslabon Armado, Peso Pluma  29/05/2023
# 1         1  Ella Baila Sola     Eslabon Armado, Peso Pluma  29/05/2023
# 2         2   WHERE SHE GOES                      Bad Bunny  29/05/2023
# 3         3  La Bebe - Remix          Yng Lvcas, Peso Pluma  29/05/2023
# 4         3  La Bebe - Remix          Yng Lvcas, Peso Pluma  29/05/2023
# ...     ...              ...                            ...         ...
# 19995     6        As It Was                   Harry Styles  21/03/2023
# 19996    77        Bad Habit                     Steve Lacy  21/03/2023
# 19997    68        Bebe Dame  Fuerza Regida, Grupo Frontera  21/03/2023
# 19998    68        Bebe Dame  Fuerza Regida, Grupo Frontera  21/03/2023
# 19999   147         Believer                Imagine Dragons  21/03/2023
#
#        Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0             0.668   0.758   -5176.0        0.033         0.483
# 1             0.668   0.758   -5176.0        0.033         0.483
# 2             0.652   0.800   -4019.0        0.061         0.143
# 3             0.812   0.479   -5678.0        0.333         0.213
# 4             0.812   0.479   -5678.0        0.333         0.213
# ...             ...     ...       ...          ...           ...
# 19995         0.520   0.731   -5338.0        0.056         0.342
# 19996         0.686   0.494   -7093.0        0.036         0.613
# 19997         0.529   0.602   -4629.0        0.046         0.299
# 19998         0.529   0.602   -4629.0        0.046         0.299
# 19999         0.776   0.780   -4374.0        0.128         0.062
#
#        Instrumentalness  Valence     Nationality      Continent  \
# 0                 0.000    0.834          Mexico  Latin-America
# 1                 0.000    0.834          Mexico  Latin-America
# 2                 0.629    0.234     Puerto Rico  Latin-America
# 3                 0.000    0.559          Mexico  Latin-America
# 4                 0.000    0.559          Mexico  Latin-America
# ...                 ...      ...             ...            ...
# 19995             0.001    0.662  United Kingdom         Europe
# 19996             0.000    0.700   United States  Anglo-America
# 19997             0.000    0.756          Mexico  Latin-America
# 19998             0.000    0.756          Mexico  Latin-America
# 19999             0.000    0.666   United States  Anglo-America
#
#                            id  \
# 0      3qQbCzHBycnDpGskqOWY0E
# 1      3qQbCzHBycnDpGskqOWY0E
# 2      7ro0hRteUMfnOioTFI5TG1
# 3      2UW7JaomAMuX9pZrjVpHAU
# 4      2UW7JaomAMuX9pZrjVpHAU
# ...                       ...
# 19995  4Dvkj6JhhA12EX05fT7y2e
# 19996  4k6Uh1HXdhtusDW5y8Gbvy
# 19997  0IKeDy5bT9G0bA7ZixRT4A
# 19998  0IKeDy5bT9G0bA7ZixRT4A
# 19999  0pqnGHJpmpxLKifKRmU6WP
#
#                                                 Song URL
# 0      https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 1      https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 2      https://open.spotify.com/track/7ro0hRteUMfnOio...
# 3      https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# 4      https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# ...                                                  ...
# 19995  https://open.spotify.com/track/4Dvkj6JhhA12EX0...
# 19996  https://open.spotify.com/track/4k6Uh1HXdhtusDW...
# 19997  https://open.spotify.com/track/0IKeDy5bT9G0bA7...
# 19998  https://open.spotify.com/track/0IKeDy5bT9G0bA7...
# 19999  https://open.spotify.com/track/0pqnGHJpmpxLKif...
#
# [20000 rows x 15 columns]

# %%
i = 0
count = 0
maxd = len(df.index)
#print(max)
for i,row in df.iterrows():
    if i-count+1>=maxd:
        break
    else:
        if df.iloc[i-count,]["Rank"] == df.iloc[i+1-count,]["Rank"]:
            temp = row
            if df.iloc[i-count,]["Nationality"] != df.iloc[i+1-count,]["Nationality"]:
                temp["Nationality"] = df.iloc[i-count,]["Nationality"]+","+df.iloc[i+1-count,]["Nationality"]
            if df.iloc[i-count,]["Continent"] != df.iloc[i+1-count,]["Continent"]:
                temp["Continent"] = df.iloc[i-count,]["Continent"]+","+df.iloc[i+1-count,]["Continent"]
            row = temp
            df = df.drop([i+1], axis=0, inplace=False)
            maxd = maxd-1
            count = count + 1
       
df
# Out:
#        Rank              Title                        Artists        Date  \
# 0         1    Ella Baila Sola     Eslabon Armado, Peso Pluma  29/05/2023
# 2         2     WHERE SHE GOES                      Bad Bunny  29/05/2023
# 3         3    La Bebe - Remix          Yng Lvcas, Peso Pluma  29/05/2023
# 5         4  Cupid - Twin Ver.                    FIFTY FIFTY  29/05/2023
# 6         5          un x100to      Grupo Frontera, Bad Bunny  29/05/2023
# ...     ...                ...                            ...         ...
# 19994   138         Apocalypse           Cigarettes After Sex  21/03/2023
# 19995     6          As It Was                   Harry Styles  21/03/2023
# 19996    77          Bad Habit                     Steve Lacy  21/03/2023
# 19997    68          Bebe Dame  Fuerza Regida, Grupo Frontera  21/03/2023
# 19999   147           Believer                Imagine Dragons  21/03/2023
#
#        Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0             0.668   0.758   -5176.0        0.033         0.483
# 2             0.652   0.800   -4019.0        0.061         0.143
# 3             0.812   0.479   -5678.0        0.333         0.213
# 5             0.783   0.592   -8332.0        0.033         0.435
# 6             0.569   0.724   -4076.0        0.047         0.228
# ...             ...     ...       ...          ...           ...
# 19994         0.369   0.467   -9018.0        0.027         0.019
# 19995         0.520   0.731   -5338.0        0.056         0.342
# 19996         0.686   0.494   -7093.0        0.036         0.613
# 19997         0.529   0.602   -4629.0        0.046         0.299
# 19999         0.776   0.780   -4374.0        0.128         0.062
#
#        Instrumentalness  Valence     Nationality      Continent  \
# 0                 0.000    0.834          Mexico  Latin-America
# 2                 0.629    0.234     Puerto Rico  Latin-America
# 3                 0.000    0.559          Mexico  Latin-America
# 5                 0.000    0.726     South Korea           Asia
# 6                 0.000    0.562          Mexico  Latin-America
# ...                 ...      ...             ...            ...
# 19994             0.460    0.174   United States  Anglo-America
# 19995             0.001    0.662  United Kingdom         Europe
# 19996             0.000    0.700   United States  Anglo-America
# 19997             0.000    0.756          Mexico  Latin-America
# 19999             0.000    0.666   United States  Anglo-America
#
#                            id  \
# 0      3qQbCzHBycnDpGskqOWY0E
# 2      7ro0hRteUMfnOioTFI5TG1
# 3      2UW7JaomAMuX9pZrjVpHAU
# 5      7FbrGaHYVDmfr7KoLIZnQ7
# 6      6pD0ufEQq0xdHSsRbg9LBK
# ...                       ...
# 19994  3AVrVz5rK8Hrqo9YGiVGN5
# 19995  4Dvkj6JhhA12EX05fT7y2e
# 19996  4k6Uh1HXdhtusDW5y8Gbvy
# 19997  0IKeDy5bT9G0bA7ZixRT4A
# 19999  0pqnGHJpmpxLKifKRmU6WP
#
#                                                 Song URL
# 0      https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 2      https://open.spotify.com/track/7ro0hRteUMfnOio...
# 3      https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# 5      https://open.spotify.com/track/7FbrGaHYVDmfr7K...
# 6      https://open.spotify.com/track/6pD0ufEQq0xdHSs...
# ...                                                  ...
# 19994  https://open.spotify.com/track/3AVrVz5rK8Hrqo9...
# 19995  https://open.spotify.com/track/4Dvkj6JhhA12EX0...
# 19996  https://open.spotify.com/track/4k6Uh1HXdhtusDW...
# 19997  https://open.spotify.com/track/0IKeDy5bT9G0bA7...
# 19999  https://open.spotify.com/track/0pqnGHJpmpxLKif...
#
# [13811 rows x 15 columns]

# %%
count = 0
uid = []
ans = [[] for _ in range(6)]
ic = 0
maxrank = 200
minrank = 1
avgrank = 100
for i, row in df.iterrows():
    #print(ic)
    ID = df.iloc[ic]["id"]
    maxrank = df.iloc[ic]["Rank"]
    minrank = df.iloc[ic]["Rank"]
    avgrank = df.iloc[ic]["Rank"]
    count = 1
    if ID not in uid:
        start_date = df.iloc[ic]["Date"]
        uid.append(ID)
        jc = 0
        for j , row2 in df.iterrows():
            #print(jc)
            if (jc!=ic):
                if(df.iloc[jc]["id"]==ID):
                    count = count + 1
                    #print(df.iloc[jc]["Date"])
                    last_date = df.iloc[jc]["Date"]
                    #df = df.drop([j],axis=0, inplace=False)
                    if df.iloc[jc]["Rank"]<maxrank:
                        maxrank = df.iloc[jc]["Rank"]
                    if df.iloc[jc]["Rank"]>minrank:
                        minrank = df.iloc[jc]["Rank"]
                    avgrank = avgrank + df.iloc[jc]["Rank"]

            jc = jc + 1
            if jc == len(df.index):
                break
    ans[0].append(count)
    ans[1].append(start_date)
    if count ==1:
        last_date = start_date
    ans[2].append(last_date)
    ans[3].append(maxrank)
    ans[4].append(minrank)
    ans[5].append(avgrank/count)
    ic = ic + 1
    if ic == len(df.index):
        break
#ans[0].append(1)
#ans[1].append(1)
#ans[2].append(1)
df = df.assign(Start_Date = ans[2])
df = df.assign(Last_Date = ans[1])
df = df.assign(MaxRank = ans[3])
df = df.assign(MinRank = ans[4])
df = df.assign(AvgRank = ans[5])
df = df.assign(DaysinTop200 = ans[0])
        
df
# Out:
#        Rank              Title                        Artists        Date  \
# 0         1    Ella Baila Sola     Eslabon Armado, Peso Pluma  29/05/2023
# 2         2     WHERE SHE GOES                      Bad Bunny  29/05/2023
# 3         3    La Bebe - Remix          Yng Lvcas, Peso Pluma  29/05/2023
# 5         4  Cupid - Twin Ver.                    FIFTY FIFTY  29/05/2023
# 6         5          un x100to      Grupo Frontera, Bad Bunny  29/05/2023
# ...     ...                ...                            ...         ...
# 19994   138         Apocalypse           Cigarettes After Sex  21/03/2023
# 19995     6          As It Was                   Harry Styles  21/03/2023
# 19996    77          Bad Habit                     Steve Lacy  21/03/2023
# 19997    68          Bebe Dame  Fuerza Regida, Grupo Frontera  21/03/2023
# 19999   147           Believer                Imagine Dragons  21/03/2023
#
#        Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0             0.668   0.758   -5176.0        0.033         0.483
# 2             0.652   0.800   -4019.0        0.061         0.143
# 3             0.812   0.479   -5678.0        0.333         0.213
# 5             0.783   0.592   -8332.0        0.033         0.435
# 6             0.569   0.724   -4076.0        0.047         0.228
# ...             ...     ...       ...          ...           ...
# 19994         0.369   0.467   -9018.0        0.027         0.019
# 19995         0.520   0.731   -5338.0        0.056         0.342
# 19996         0.686   0.494   -7093.0        0.036         0.613
# 19997         0.529   0.602   -4629.0        0.046         0.299
# 19999         0.776   0.780   -4374.0        0.128         0.062
#
#        Instrumentalness  ...     Nationality      Continent  \
# 0                 0.000  ...          Mexico  Latin-America
# 2                 0.629  ...     Puerto Rico  Latin-America
# 3                 0.000  ...          Mexico  Latin-America
# 5                 0.000  ...     South Korea           Asia
# 6                 0.000  ...          Mexico  Latin-America
# ...                 ...  ...             ...            ...
# 19994             0.460  ...   United States  Anglo-America
# 19995             0.001  ...  United Kingdom         Europe
# 19996             0.000  ...   United States  Anglo-America
# 19997             0.000  ...          Mexico  Latin-America
# 19999             0.000  ...   United States  Anglo-America
#
#                            id  \
# 0      3qQbCzHBycnDpGskqOWY0E
# 2      7ro0hRteUMfnOioTFI5TG1
# 3      2UW7JaomAMuX9pZrjVpHAU
# 5      7FbrGaHYVDmfr7KoLIZnQ7
# 6      6pD0ufEQq0xdHSsRbg9LBK
# ...                       ...
# 19994  3AVrVz5rK8Hrqo9YGiVGN5
# 19995  4Dvkj6JhhA12EX05fT7y2e
# 19996  4k6Uh1HXdhtusDW5y8Gbvy
# 19997  0IKeDy5bT9G0bA7ZixRT4A
# 19999  0pqnGHJpmpxLKifKRmU6WP
#
#                                                 Song URL  Start_Date  \
# 0      https://open.spotify.com/track/3qQbCzHBycnDpGs...  28/04/2023
# 2      https://open.spotify.com/track/7ro0hRteUMfnOio...  19/05/2023
# 3      https://open.spotify.com/track/2UW7JaomAMuX9pZ...  22/03/2023
# 5      https://open.spotify.com/track/7FbrGaHYVDmfr7K...  01/04/2023
# 6      https://open.spotify.com/track/6pD0ufEQq0xdHSs...  17/04/2023
# ...                                                  ...         ...
# 19994  https://open.spotify.com/track/3AVrVz5rK8Hrqo9...  21/03/2023
# 19995  https://open.spotify.com/track/4Dvkj6JhhA12EX0...  21/03/2023
# 19996  https://open.spotify.com/track/4k6Uh1HXdhtusDW...  21/03/2023
# 19997  https://open.spotify.com/track/0IKeDy5bT9G0bA7...  21/03/2023
# 19999  https://open.spotify.com/track/0pqnGHJpmpxLKif...  21/03/2023
#
#         Last_Date MaxRank  MinRank     AvgRank  DaysinTop200
# 0      29/05/2023       1        2    1.468750            32
# 2      29/05/2023       1        4    2.090909            11
# 3      29/05/2023       2       77    6.057971            69
# 5      29/05/2023       3       25    7.474576            59
# 6      29/05/2023       1        5    1.953488            43
# ...           ...     ...      ...         ...           ...
# 19994  21/03/2023     138      138  138.000000             1
# 19995  21/03/2023       6        6    6.000000             1
# 19996  21/03/2023      77       77   77.000000             1
# 19997  21/03/2023      68       68   68.000000             1
# 19999  21/03/2023     147      147  147.000000             1
#
# [13811 rows x 21 columns]

# %%
df = df.drop_duplicates(subset=["id"], keep='first')
df
# Out:
#        Rank              Title                     Artists        Date  \
# 0         1    Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 2         2     WHERE SHE GOES                   Bad Bunny  29/05/2023
# 3         3    La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
# 5         4  Cupid - Twin Ver.                 FIFTY FIFTY  29/05/2023
# 6         5          un x100to   Grupo Frontera, Bad Bunny  29/05/2023
# ...     ...                ...                         ...         ...
# 19370   110          The Light                  Juice WRLD  24/03/2023
# 19512   164              Jaded                 Miley Cyrus  23/03/2023
# 19537   174  lo que hay x aquí                      Rels B  23/03/2023
# 19804   195         In Ha Mood                   Ice Spice  22/03/2023
# 19987   199        After Hours                  The Weeknd  21/03/2023
#
#        Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0             0.668   0.758   -5176.0        0.033         0.483
# 2             0.652   0.800   -4019.0        0.061         0.143
# 3             0.812   0.479   -5678.0        0.333         0.213
# 5             0.783   0.592   -8332.0        0.033         0.435
# 6             0.569   0.724   -4076.0        0.047         0.228
# ...             ...     ...       ...          ...           ...
# 19370         0.634   0.844   -3809.0        0.042         0.077
# 19512         0.496   0.593   -5154.0        0.029         0.048
# 19537         0.807   0.490   -7112.0        0.213         0.522
# 19804         0.768   0.740   -6595.0        0.336         0.696
# 19987         0.664   0.572   -6099.0        0.031         0.081
#
#        Instrumentalness  ...    Nationality      Continent  \
# 0                 0.000  ...         Mexico  Latin-America
# 2                 0.629  ...    Puerto Rico  Latin-America
# 3                 0.000  ...         Mexico  Latin-America
# 5                 0.000  ...    South Korea           Asia
# 6                 0.000  ...         Mexico  Latin-America
# ...                 ...  ...            ...            ...
# 19370             0.000  ...  United States  Anglo-America
# 19512             0.000  ...  United States  Anglo-America
# 19537             0.000  ...          Spain         Europe
# 19804             0.000  ...         France         Europe
# 19987             0.006  ...         Canada  Anglo-America
#
#                            id  \
# 0      3qQbCzHBycnDpGskqOWY0E
# 2      7ro0hRteUMfnOioTFI5TG1
# 3      2UW7JaomAMuX9pZrjVpHAU
# 5      7FbrGaHYVDmfr7KoLIZnQ7
# 6      6pD0ufEQq0xdHSsRbg9LBK
# ...                       ...
# 19370  6j5BK1cFX9TjJd5EXHGgAn
# 19512  3AAY8YicetRPlDAkibHLiS
# 19537  5IlLm20JXhKbMtsH20NblC
# 19804  0yUaLqhsVsguBpoOPL4cO7
# 19987  2p8IUWQDrpjuFltbdgLOag
#
#                                                 Song URL  Start_Date  \
# 0      https://open.spotify.com/track/3qQbCzHBycnDpGs...  28/04/2023
# 2      https://open.spotify.com/track/7ro0hRteUMfnOio...  19/05/2023
# 3      https://open.spotify.com/track/2UW7JaomAMuX9pZ...  22/03/2023
# 5      https://open.spotify.com/track/7FbrGaHYVDmfr7K...  01/04/2023
# 6      https://open.spotify.com/track/6pD0ufEQq0xdHSs...  17/04/2023
# ...                                                  ...         ...
# 19370  https://open.spotify.com/track/6j5BK1cFX9TjJd5...  23/03/2023
# 19512  https://open.spotify.com/track/3AAY8YicetRPlDA...  22/03/2023
# 19537  https://open.spotify.com/track/5IlLm20JXhKbMts...  22/03/2023
# 19804  https://open.spotify.com/track/0yUaLqhsVsguBpo...  22/03/2023
# 19987  https://open.spotify.com/track/2p8IUWQDrpjuFlt...  21/03/2023
#
#         Last_Date MaxRank  MinRank     AvgRank  DaysinTop200
# 0      29/05/2023       1        2    1.468750            32
# 2      29/05/2023       1        4    2.090909            11
# 3      29/05/2023       2       77    6.057971            69
# 5      29/05/2023       3       25    7.474576            59
# 6      29/05/2023       1        5    1.953488            43
# ...           ...     ...      ...         ...           ...
# 19370  24/03/2023     110      173  141.500000             2
# 19512  23/03/2023      97      164  130.500000             2
# 19537  23/03/2023     147      174  160.500000             2
# 19804  22/03/2023     195      195  195.000000             1
# 19987  21/03/2023     199      199  199.000000             1
#
# [438 rows x 21 columns]

# %%
df = df.drop(["Rank","Title", "Artists","Date","id","Song URL",],axis=1)

# %%
df.to_csv('current.csv')

# %%
df=pd.read_csv("current.csv")
df = df.drop("Unnamed: 0",axis = 1)
df
# Out:
#      Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0           0.668   0.758   -5176.0        0.033         0.483
# 1           0.652   0.800   -4019.0        0.061         0.143
# 2           0.812   0.479   -5678.0        0.333         0.213
# 3           0.783   0.592   -8332.0        0.033         0.435
# 4           0.569   0.724   -4076.0        0.047         0.228
# ..            ...     ...       ...          ...           ...
# 433         0.634   0.844   -3809.0        0.042         0.077
# 434         0.496   0.593   -5154.0        0.029         0.048
# 435         0.807   0.490   -7112.0        0.213         0.522
# 436         0.768   0.740   -6595.0        0.336         0.696
# 437         0.664   0.572   -6099.0        0.031         0.081
#
#      Instrumentalness  Valence  Nationality  Continent  Start_Date  Last_Date  \
# 0               0.000    0.834           18          4          51         63
# 1               0.629    0.234           22          4          31         63
# 2               0.000    0.559           18          4          35         63
# 3               0.000    0.726           24          2           0         63
# 4               0.000    0.562           18          4          27         63
# ..                ...      ...          ...        ...         ...        ...
# 433             0.000    0.246           30          1          38         48
# 434             0.000    0.177           30          1          35         46
# 435             0.000    0.739           25          3          35         46
# 436             0.000    0.532            9          3          35         43
# 437             0.006    0.143            5          1          33         40
#
#      MaxRank  MinRank     AvgRank  DaysinTop200  HitorNot
# 0          1        2    1.468750            32         0
# 1          1        4    2.090909            11         0
# 2          2       77    6.057971            69         1
# 3          3       25    7.474576            59         0
# 4          1        5    1.953488            43         0
# ..       ...      ...         ...           ...       ...
# 433      110      173  141.500000             2         0
# 434       97      164  130.500000             2         0
# 435      147      174  160.500000             2         0
# 436      195      195  195.000000             1         0
# 437      199      199  199.000000             1         0
#
# [438 rows x 16 columns]

# %%
l = []
for i,row in df.iterrows():
    if row['DaysinTop200']>67:
        l.append("Yes")
    else:
        l.append("No")
df = df.assign(HitorNot = l)

# %%
from sklearn.preprocessing import LabelEncoder
labelenc = LabelEncoder()
#df['# of Artist'] = labelenc.fit_transform(df['# of Artist'])
#df['# of Nationality'] = labelenc.fit_transform(df['# of Nationality'])
df['Nationality'] = labelenc.fit_transform(df['Nationality'])
df['Continent'] = labelenc.fit_transform(df['Continent'])
df['Start_Date'] = labelenc.fit_transform(df['Start_Date'])
df['Last_Date'] = labelenc.fit_transform(df['Last_Date'])
#df['DaysinTop20'] = labelenc.fit_transform(df['DaysinTop20'])
df['HitorNot'] = labelenc.fit_transform(df['HitorNot'])
df.iloc[:10,:]
# Out:
#     Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0          0.668   0.758   -5176.0        0.033         0.483
# 2          0.652   0.800   -4019.0        0.061         0.143
# 3          0.812   0.479   -5678.0        0.333         0.213
# 5          0.783   0.592   -8332.0        0.033         0.435
# 6          0.569   0.724   -4076.0        0.047         0.228
# 8          0.707   0.681   -4325.0        0.067         0.063
# 9          0.508   0.430   -9475.0        0.034         0.830
# 10         0.644   0.735   -5747.0        0.039         0.052
# 11         0.520   0.731   -5338.0        0.056         0.342
# 12         0.720   0.630   -3547.0        0.277         0.673
#
#     Instrumentalness  Valence  Nationality  Continent  Start_Date  Last_Date  \
# 0              0.000    0.834           18          4          51         63
# 2              0.629    0.234           22          4          31         63
# 3              0.000    0.559           18          4          35         63
# 5              0.000    0.726           24          2           0         63
# 6              0.000    0.562           18          4          27         63
# 8              0.000    0.646           30          1          35         63
# 9              0.000    0.324           30          1          22         63
# 10             0.144    0.418           30          1          35         63
# 11             0.001    0.662           29          3          33         63
# 12             0.000    0.607            6          4          35         63
#
#     MaxRank  MinRank   AvgRank  DaysinTop200  HitorNot
# 0         1        2  1.468750            32         0
# 2         1        4  2.090909            11         0
# 3         2       77  6.057971            69         1
# 5         3       25  7.474576            59         0
# 6         1        5  1.953488            43         0
# 8         1        9  3.521739            69         1
# 9         4       11  7.000000            46         0
# 10        2       11  5.594203            69         1
# 11        6       14  9.028571            70         1
# 12        2       14  6.797101            69         1

# %%
df.describe(include='all')
# Out:
#        Danceability      Energy      Loudness  Speechiness  Acousticness  \
# count    438.000000  438.000000    438.000000   438.000000    438.000000
# mean       0.665543    0.646283  -5474.658936     0.095486      0.272820
# std        0.140633    0.170491   3152.445069     0.094379      0.255723
# min        0.188000    0.102000 -17621.000000     0.023000      0.000000
# 25%        0.571000    0.531000  -7114.250000     0.039000      0.063000
# 50%        0.683500    0.668000  -5378.500000     0.054000      0.181500
# 75%        0.773500    0.780750  -4020.000000     0.101750      0.431000
# max        0.957000    0.979000     -0.514000     0.637000      0.985000
#
#        Instrumentalness     Valence  Nationality   Continent  Start_Date  \
# count        438.000000  438.000000   438.000000  438.000000  438.000000
# mean           0.021642    0.511002    22.063927    2.280822   33.011416
# std            0.110244    0.231482     9.669151    1.276848   12.545473
# min            0.000000    0.039000     0.000000    0.000000    0.000000
# 25%            0.000000    0.346250    18.000000    1.000000   31.250000
# 50%            0.000000    0.506500    25.500000    2.000000   35.000000
# 75%            0.000000    0.698000    30.000000    3.000000   35.000000
# max            0.901000    0.970000    31.000000    6.000000   57.000000
#
#         Last_Date     MaxRank     MinRank     AvgRank  DaysinTop200  \
# count  438.000000  438.000000  438.000000  438.000000    438.000000
# mean    48.764840   94.086758  153.933790  121.693188     31.531963
# std     19.433674   59.604353   55.170115   54.922950     27.663847
# min      0.000000    1.000000    2.000000    1.468750      1.000000
# 25%     37.000000   43.000000  124.250000   79.742391      4.000000
# 50%     63.000000   90.000000  180.000000  129.442308     22.000000
# 75%     63.000000  145.000000  197.000000  168.604301     67.000000
# max     66.000000  200.000000  200.000000  200.000000     70.000000
#
#          HitorNot
# count  438.000000
# mean     0.244292
# std      0.430158
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
#y = np.array(df['HitorNot'], dtype='object')
y = df.loc[:,'HitorNot']
x = df.drop(columns=['HitorNot','DaysinTop200','Start_Date','Last_Date'],inplace = False)
mms = MinMaxScaler()
ss = StandardScaler()
x = ss.fit_transform(x)
x = mms.fit_transform(x)
x = pd.DataFrame(x, columns=df.drop(columns=['HitorNot','DaysinTop200','Start_Date','Last_Date']).columns)
x
# Out:
#      Danceability    Energy  Loudness  Speechiness  Acousticness  \
# 0        0.624187  0.748005  0.706280     0.016287      0.490355
# 1        0.603381  0.795895  0.771942     0.061889      0.145178
# 2        0.811443  0.429875  0.677791     0.504886      0.216244
# 3        0.773732  0.558723  0.527170     0.016287      0.441624
# 4        0.495449  0.709236  0.768708     0.039088      0.231472
# ..            ...       ...       ...          ...           ...
# 433      0.579974  0.846066  0.783860     0.030945      0.078173
# 434      0.400520  0.559863  0.707529     0.009772      0.048731
# 435      0.804941  0.442417  0.596408     0.309446      0.529949
# 436      0.754226  0.727480  0.625749     0.509772      0.706599
# 437      0.618986  0.535918  0.653898     0.013029      0.082234
#
#      Instrumentalness   Valence  Nationality  Continent   MaxRank   MinRank  \
# 0            0.000000  0.853921     0.580645   0.666667  0.000000  0.000000
# 1            0.698113  0.209452     0.709677   0.666667  0.000000  0.010101
# 2            0.000000  0.558539     0.580645   0.666667  0.005025  0.378788
# 3            0.000000  0.737916     0.774194   0.333333  0.010050  0.116162
# 4            0.000000  0.561762     0.580645   0.666667  0.000000  0.015152
# ..                ...       ...          ...        ...       ...       ...
# 433          0.000000  0.222342     0.967742   0.166667  0.547739  0.863636
# 434          0.000000  0.148228     0.967742   0.166667  0.482412  0.818182
# 435          0.000000  0.751880     0.806452   0.500000  0.733668  0.868687
# 436          0.000000  0.529538     0.290323   0.500000  0.974874  0.974747
# 437          0.006659  0.111708     0.161290   0.166667  0.994975  0.994949
#
#       AvgRank
# 0    0.000000
# 1    0.003134
# 2    0.023116
# 3    0.030251
# 4    0.002442
# ..        ...
# 433  0.705336
# 434  0.649929
# 435  0.801039
# 436  0.974815
# 437  0.994963
#
# [438 rows x 12 columns]

# %%
y
# Out:
# 0        0
# 2        0
# 3        1
# 5        0
# 6        0
#         ..
# 19370    0
# 19512    0
# 19537    0
# 19804    0
# 19987    0
# Name: HitorNot, Length: 438, dtype: int32

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = .75)

# %%
def makeCountPlot(data, width=0, height=4, hue=None):
  if width == 0:
    width = len(data.unique())*1.25
  plt.figure(figsize=(width, height))
  sns.countplot(x=data, hue=hue)

# %%
makeCountPlot(data=y_train)

# %%
makeCountPlot(data=y_test)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
# model = GaussianNB()
#model = DecisionTreeClassifier()
model = RandomForestClassifier(n_estimators=1400, max_depth=500, max_features=None)

#clf.fit(x_train,y_train)

#rfcpred = clf.predict(x_val)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=500, max_features=None, n_estimators=1400)

# %%
pred = model.predict(x_test)
print(classification_report(pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.92        94
#            1       0.52      0.75      0.62        16
#
#     accuracy                           0.86       110
#    macro avg       0.74      0.82      0.77       110
# weighted avg       0.89      0.86      0.87       110

# %%
sns.heatmap(confusion_matrix(pred, y_test), annot=True, cmap='Blues_r')
# Out:
# <Axes: >

# %%
sdf = df.drop(['DaysinTop200','Start_Date','Last_Date',],axis =1,inplace = False)
plt.figure(figsize=(12, 10)) # Set the figure size
sns.heatmap(sdf.corr(), annot=True) # Print the heatmap
# Out:
# <Axes: >
